# %%
import numpy as np

# %% [markdown]
# # Basic Math

# %%
# np.sqrt(x)
# np.power(x, 2)
# np.abs(x)
# np.round(x, 2)

# %% [markdown]
# # Trigonometry

# %%
# np.sin(x)
# np.cos(x)
# np.tan(x)
# np.arcsin(x)
# np.deg2rad(degrees)
# np.rad2deg(radians)

# %% [markdown]
# # Statistics

# %%
# np.mean(x)
# np.median(x)
# np.std(x)
# np.var(x)
# np.percentile(x, 90)

# %% [markdown]
# # Linear Algebra

# %%
# np.dot(A, B)
# np.linalg.inv(A)
# np.linalg.det(A)
# np.linalg.eig(A)
