# %%
import numpy as np

# %% [markdown]
# # Create an array of student marks. Find the average, max, mean, percentage, Failures and Toppers.

# %%
totalMarks = 1100
marks = np.random.randint(1, 1100, 100)
marks
# Out:
# array([ 488,  586,  294,  170,  806,  861,  618,  329,  894,  858,  610,
#          98,  817,  906,  308,  180,    5,  151,  774,  787,  813,  678,
#        1028,  974, 1045,  375,  870,  462,  928,  722,  677,  516,  414,
#         661,  439,   91,  470,  505,  716,  359,  352,  957,   97,   55,
#         783,   40, 1067,   45,  526,  952,  240,  470,  899,  381,  242,
#         688,  693,  928,  367,  770,   68,  444,  128,  112,  561,  350,
#         197,  150,  174,  410,  310,  847,  998,  997,  664,  234,  275,
#         706,  368,  749,  758,  646,  284,  277,  514,   50,  776,   85,
#         658,  262,  289,  781,  497,   14,   95,  805,  399,  567,  694,
#         392], dtype=int32)

# %% [markdown]
# Average

# %%
avg = np.average(marks)
avg
# Out:
# np.float64(514.2)

# %% [markdown]
# Max

# %%
maximun = np.max(marks)
maximun
# Out:
# np.int32(1067)

# %% [markdown]
# Mean

# %%
mean = np.mean(marks)
mean
# Out:
# np.float64(514.2)

# %%
percentage = marks * 100/ totalMarks
percentage = np.round(percentage, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 percentage = marks * 100/ totalMarks
# ----> 2 percentage = round(percentage, 2)
#
# TypeError: type numpy.ndarray doesn't define __round__ method
